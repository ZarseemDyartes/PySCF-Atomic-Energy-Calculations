# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['He',0,bse.get_basis('STO-2G',elements=[2],fmt='nwchem',header=False)],['Li',1,bse.get_basis('STO-2G',elements=[3],fmt='nwchem',header=False)],['Be',0,bse.get_basis('STO-2G',elements=[4],fmt='nwchem',header=False)],['B',1,bse.get_basis('STO-2G',elements=[5],fmt='nwchem',header=False)],['C',2,bse.get_basis('STO-2G',elements=[6],fmt='nwchem',header=False)],['N',3,bse.get_basis('STO-2G',elements=[7],fmt='nwchem',header=False)],['O',2,bse.get_basis('STO-2G',elements=[8],fmt='nwchem',header=False)],['F',1,bse.get_basis('STO-2G',elements=[9],fmt='nwchem',header=False)],['Ne',0,bse.get_basis('STO-2G',elements=[10],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-2G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['He',0,bse.get_basis('STO-3G',elements=[2],fmt='nwchem',header=False)],['Li',1,bse.get_basis('STO-3G',elements=[3],fmt='nwchem',header=False)],['Be',0,bse.get_basis('STO-3G',elements=[4],fmt='nwchem',header=False)],['B',1,bse.get_basis('STO-3G',elements=[5],fmt='nwchem',header=False)],['C',2,bse.get_basis('STO-3G',elements=[6],fmt='nwchem',header=False)],['N',3,bse.get_basis('STO-3G',elements=[7],fmt='nwchem',header=False)],['O',2,bse.get_basis('STO-3G',elements=[8],fmt='nwchem',header=False)],['F',1,bse.get_basis('STO-3G',elements=[9],fmt='nwchem',header=False)],['Ne',0,bse.get_basis('STO-3G',elements=[10],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-3G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['He',0,bse.get_basis('STO-4G',elements=[2],fmt='nwchem',header=False)],['Li',1,bse.get_basis('STO-4G',elements=[3],fmt='nwchem',header=False)],['Be',0,bse.get_basis('STO-4G',elements=[4],fmt='nwchem',header=False)],['B',1,bse.get_basis('STO-4G',elements=[5],fmt='nwchem',header=False)],['C',2,bse.get_basis('STO-4G',elements=[6],fmt='nwchem',header=False)],['N',3,bse.get_basis('STO-4G',elements=[7],fmt='nwchem',header=False)],['O',2,bse.get_basis('STO-4G',elements=[8],fmt='nwchem',header=False)],['F',1,bse.get_basis('STO-4G',elements=[9],fmt='nwchem',header=False)],['Ne',0,bse.get_basis('STO-4G',elements=[10],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-4G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['He',0,bse.get_basis('STO-5G',elements=[2],fmt='nwchem',header=False)],['Li',1,bse.get_basis('STO-5G',elements=[3],fmt='nwchem',header=False)],['Be',0,bse.get_basis('STO-5G',elements=[4],fmt='nwchem',header=False)],['B',1,bse.get_basis('STO-5G',elements=[5],fmt='nwchem',header=False)],['C',2,bse.get_basis('STO-5G',elements=[6],fmt='nwchem',header=False)],['N',3,bse.get_basis('STO-5G',elements=[7],fmt='nwchem',header=False)],['O',2,bse.get_basis('STO-5G',elements=[8],fmt='nwchem',header=False)],['F',1,bse.get_basis('STO-5G',elements=[9],fmt='nwchem',header=False)],['Ne',0,bse.get_basis('STO-5G',elements=[10],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-5G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['He',0,bse.get_basis('STO-6G',elements=[2],fmt='nwchem',header=False)],['Li',1,bse.get_basis('STO-6G',elements=[3],fmt='nwchem',header=False)],['Be',0,bse.get_basis('STO-6G',elements=[4],fmt='nwchem',header=False)],['B',1,bse.get_basis('STO-6G',elements=[5],fmt='nwchem',header=False)],['C',2,bse.get_basis('STO-6G',elements=[6],fmt='nwchem',header=False)],['N',3,bse.get_basis('STO-6G',elements=[7],fmt='nwchem',header=False)],['O',2,bse.get_basis('STO-6G',elements=[8],fmt='nwchem',header=False)],['F',1,bse.get_basis('STO-6G',elements=[9],fmt='nwchem',header=False)],['Ne',0,bse.get_basis('STO-6G',elements=[10],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-6G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

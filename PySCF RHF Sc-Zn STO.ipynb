# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Sc',1,bse.get_basis('STO-2G',elements=[21],fmt='nwchem',header=False)],['Ti',2,bse.get_basis('STO-2G',elements=[22],fmt='nwchem',header=False)],['V',3,bse.get_basis('STO-2G',elements=[23],fmt='nwchem',header=False)],['Cr',6,bse.get_basis('STO-2G',elements=[24],fmt='nwchem',header=False)],['Mn',5,bse.get_basis('STO-2G',elements=[25],fmt='nwchem',header=False)],['Fe',4,bse.get_basis('STO-2G',elements=[26],fmt='nwchem',header=False)],['Co',3,bse.get_basis('STO-2G',elements=[27],fmt='nwchem',header=False)],['Ni',2,bse.get_basis('STO-2G',elements=[28],fmt='nwchem',header=False)],['Cu',1,bse.get_basis('STO-2G',elements=[29],fmt='nwchem',header=False)],['Zn',0,bse.get_basis('STO-2G',elements=[30],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-2G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Sc',1,bse.get_basis('STO-3G',elements=[21],fmt='nwchem',header=False)],['Ti',2,bse.get_basis('STO-3G',elements=[22],fmt='nwchem',header=False)],['V',3,bse.get_basis('STO-3G',elements=[23],fmt='nwchem',header=False)],['Cr',6,bse.get_basis('STO-3G',elements=[24],fmt='nwchem',header=False)],['Mn',5,bse.get_basis('STO-3G',elements=[25],fmt='nwchem',header=False)],['Fe',4,bse.get_basis('STO-3G',elements=[26],fmt='nwchem',header=False)],['Co',3,bse.get_basis('STO-3G',elements=[27],fmt='nwchem',header=False)],['Ni',2,bse.get_basis('STO-3G',elements=[28],fmt='nwchem',header=False)],['Cu',1,bse.get_basis('STO-3G',elements=[29],fmt='nwchem',header=False)],['Zn',0,bse.get_basis('STO-3G',elements=[30],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-3G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Sc',1,bse.get_basis('STO-4G',elements=[21],fmt='nwchem',header=False)],['Ti',2,bse.get_basis('STO-4G',elements=[22],fmt='nwchem',header=False)],['V',3,bse.get_basis('STO-4G',elements=[23],fmt='nwchem',header=False)],['Cr',6,bse.get_basis('STO-4G',elements=[24],fmt='nwchem',header=False)],['Mn',5,bse.get_basis('STO-4G',elements=[25],fmt='nwchem',header=False)],['Fe',4,bse.get_basis('STO-4G',elements=[26],fmt='nwchem',header=False)],['Co',3,bse.get_basis('STO-4G',elements=[27],fmt='nwchem',header=False)],['Ni',2,bse.get_basis('STO-4G',elements=[28],fmt='nwchem',header=False)],['Cu',1,bse.get_basis('STO-4G',elements=[29],fmt='nwchem',header=False)],['Zn',0,bse.get_basis('STO-4G',elements=[30],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-4G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Sc',1,bse.get_basis('STO-5G',elements=[21],fmt='nwchem',header=False)],['Ti',2,bse.get_basis('STO-5G',elements=[22],fmt='nwchem',header=False)],['V',3,bse.get_basis('STO-5G',elements=[23],fmt='nwchem',header=False)],['Cr',6,bse.get_basis('STO-5G',elements=[24],fmt='nwchem',header=False)],['Mn',5,bse.get_basis('STO-5G',elements=[25],fmt='nwchem',header=False)],['Fe',4,bse.get_basis('STO-5G',elements=[26],fmt='nwchem',header=False)],['Co',3,bse.get_basis('STO-5G',elements=[27],fmt='nwchem',header=False)],['Ni',2,bse.get_basis('STO-5G',elements=[28],fmt='nwchem',header=False)],['Cu',1,bse.get_basis('STO-5G',elements=[29],fmt='nwchem',header=False)],['Zn',0,bse.get_basis('STO-5G',elements=[30],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-5G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Sc',1,bse.get_basis('STO-6G',elements=[21],fmt='nwchem',header=False)],['Ti',2,bse.get_basis('STO-6G',elements=[22],fmt='nwchem',header=False)],['V',3,bse.get_basis('STO-6G',elements=[23],fmt='nwchem',header=False)],['Cr',6,bse.get_basis('STO-6G',elements=[24],fmt='nwchem',header=False)],['Mn',5,bse.get_basis('STO-6G',elements=[25],fmt='nwchem',header=False)],['Fe',4,bse.get_basis('STO-6G',elements=[26],fmt='nwchem',header=False)],['Co',3,bse.get_basis('STO-6G',elements=[27],fmt='nwchem',header=False)],['Ni',2,bse.get_basis('STO-6G',elements=[28],fmt='nwchem',header=False)],['Cu',1,bse.get_basis('STO-6G',elements=[29],fmt='nwchem',header=False)],['Zn',0,bse.get_basis('STO-6G',elements=[30],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-6G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

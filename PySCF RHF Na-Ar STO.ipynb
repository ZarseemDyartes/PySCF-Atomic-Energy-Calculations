# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Na',1,bse.get_basis('STO-2G',elements=[11],fmt='nwchem',header=False)],['Mg',0,bse.get_basis('STO-2G',elements=[12],fmt='nwchem',header=False)],['Al',1,bse.get_basis('STO-2G',elements=[13],fmt='nwchem',header=False)],['Si',2,bse.get_basis('STO-2G',elements=[14],fmt='nwchem',header=False)],['P',3,bse.get_basis('STO-2G',elements=[15],fmt='nwchem',header=False)],['S',2,bse.get_basis('STO-2G',elements=[16],fmt='nwchem',header=False)],['Cl',1,bse.get_basis('STO-2G',elements=[17],fmt='nwchem',header=False)],['Ar',0,bse.get_basis('STO-2G',elements=[18],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-2G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Na',1,bse.get_basis('STO-3G',elements=[11],fmt='nwchem',header=False)],['Mg',0,bse.get_basis('STO-3G',elements=[12],fmt='nwchem',header=False)],['Al',1,bse.get_basis('STO-3G',elements=[13],fmt='nwchem',header=False)],['Si',2,bse.get_basis('STO-3G',elements=[14],fmt='nwchem',header=False)],['P',3,bse.get_basis('STO-3G',elements=[15],fmt='nwchem',header=False)],['S',2,bse.get_basis('STO-3G',elements=[16],fmt='nwchem',header=False)],['Cl',1,bse.get_basis('STO-3G',elements=[17],fmt='nwchem',header=False)],['Ar',0,bse.get_basis('STO-3G',elements=[18],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-3G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Na',1,bse.get_basis('STO-4G',elements=[11],fmt='nwchem',header=False)],['Mg',0,bse.get_basis('STO-4G',elements=[12],fmt='nwchem',header=False)],['Al',1,bse.get_basis('STO-4G',elements=[13],fmt='nwchem',header=False)],['Si',2,bse.get_basis('STO-4G',elements=[14],fmt='nwchem',header=False)],['P',3,bse.get_basis('STO-4G',elements=[15],fmt='nwchem',header=False)],['S',2,bse.get_basis('STO-4G',elements=[16],fmt='nwchem',header=False)],['Cl',1,bse.get_basis('STO-4G',elements=[17],fmt='nwchem',header=False)],['Ar',0,bse.get_basis('STO-4G',elements=[18],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-4G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Na',1,bse.get_basis('STO-5G',elements=[11],fmt='nwchem',header=False)],['Mg',0,bse.get_basis('STO-5G',elements=[12],fmt='nwchem',header=False)],['Al',1,bse.get_basis('STO-5G',elements=[13],fmt='nwchem',header=False)],['Si',2,bse.get_basis('STO-5G',elements=[14],fmt='nwchem',header=False)],['P',3,bse.get_basis('STO-5G',elements=[15],fmt='nwchem',header=False)],['S',2,bse.get_basis('STO-5G',elements=[16],fmt='nwchem',header=False)],['Cl',1,bse.get_basis('STO-5G',elements=[17],fmt='nwchem',header=False)],['Ar',0,bse.get_basis('STO-5G',elements=[18],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-5G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()

# %%
from pyscf import gto,scf,cc
import basis_set_exchange as bse
import matplotlib.pyplot as plt
element = [['Na',1,bse.get_basis('STO-6G',elements=[11],fmt='nwchem',header=False)],['Mg',0,bse.get_basis('STO-6G',elements=[12],fmt='nwchem',header=False)],['Al',1,bse.get_basis('STO-6G',elements=[13],fmt='nwchem',header=False)],['Si',2,bse.get_basis('STO-6G',elements=[14],fmt='nwchem',header=False)],['P',3,bse.get_basis('STO-6G',elements=[15],fmt='nwchem',header=False)],['S',2,bse.get_basis('STO-6G',elements=[16],fmt='nwchem',header=False)],['Cl',1,bse.get_basis('STO-6G',elements=[17],fmt='nwchem',header=False)],['Ar',0,bse.get_basis('STO-6G',elements=[18],fmt='nwchem',header=False)]]
rhf = []
data = [['STO-6G']]
for dp in range(len(element)):
    rhf.append([])
    
def hf(a,b,s,n):
    mol = gto.Mole()
    mol.build(
        symmetry = 'D2h',
        atom = [[a,(0,0,0)], ],
            #a - String variable, input symbol of element
        basis = gto.basis.parse(b),
            #bset - String variable, input basis set
        spin = s
            #s - Integer variable, input number of unpaired electrons
    )
    mol.verbose = 0
    mf = mol.RHF().run()
    rhf[n].append(mf.e_tot)
            #n - Integer variable
            
for atom in element:
    hf(atom[0],atom[2], atom[1],element.index(atom))
data[0].insert(0,'RHF Energy')
for energy in range(len(rhf)):
    data.append(rhf[energy])
for symbol in range(len(element)):
    rhf[symbol].insert(0,element[symbol][0])
    
fig, ax = plt.subplots()
table2 = ax.table(cellText=data, loc = 'center')
table2.set_fontsize(25)
table2.scale(10,5)
ax.axis('off')
plt.show()
